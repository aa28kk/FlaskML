# %% [markdown]
# Install Packages

# %%
# !pip install flask-ngrok
# !pip install opencv-python
# Out:
# Requirement already satisfied: flask-ngrok in c:\users\ananya\appdata\local\programs\python\python311\lib\site-packages (0.0.25)
# Requirement already satisfied: Flask>=0.8 in c:\users\ananya\appdata\local\programs\python\python311\lib\site-packages (from flask-ngrok) (3.1.3)
# Requirement already satisfied: requests in c:\users\ananya\appdata\local\programs\python\python311\lib\site-packages (from flask-ngrok) (2.33.1)
# Requirement already satisfied: blinker>=1.9.0 in c:\users\ananya\appdata\local\programs\python\python311\lib\site-packages (from Flask>=0.8->flask-ngrok) (1.9.0)
# Requirement already satisfied: click>=8.1.3 in c:\users\ananya\appdata\local\programs\python\python311\lib\site-packages (from Flask>=0.8->flask-ngrok) (8.3.1)
# Requirement already satisfied: itsdangerous>=2.2.0 in c:\users\ananya\appdata\local\programs\python\python311\lib\site-packages (from Flask>=0.8->flask-ngrok) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in c:\users\ananya\appdata\local\programs\python\python311\lib\site-packages (from Flask>=0.8->flask-ngrok) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in c:\users\ananya\appdata\local\programs\python\python311\lib\site-packages (from Flask>=0.8->flask-ngrok) (3.0.3)
# Requirement already satisfied: werkzeug>=3.1.0 in c:\users\ananya\appdata\local\programs\python\python311\lib\site-packages (from Flask>=0.8->flask-ngrok) (3.1.7)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\ananya\appdata\local\programs\python\python311\lib\site-packages (from requests->flask-ngrok) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ananya\appdata\local\programs\python\python311\lib\site-packages (from requests->flask-ngrok) (3.11)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\ananya\appdata\local\programs\python\python311\lib\site-packages (from requests->flask-ngrok) (2.6.3)
# Requirement already satisfied: certifi>=2023.5.7 in c:\users\ananya\appdata\local\programs\python\python311\lib\site-packages (from requests->flask-ngrok) (2026.2.25)
# Requirement already satisfied: colorama in c:\users\ananya\appdata\roaming\python\python311\site-packages (from click>=8.1.3->Flask>=0.8->flask-ngrok) (0.4.6)
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: opencv-python in c:\users\ananya\appdata\local\programs\python\python311\lib\site-packages (4.13.0.92)
# Requirement already satisfied: numpy>=2 in c:\users\ananya\appdata\local\programs\python\python311\lib\site-packages (from opencv-python) (2.4.4)
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# Run Server!

# %%
# Flask utils
from flask import Flask, request, render_template
import os
import cv2
import pickle as pkl

# Initialize a Flask app and connect with the server
app = Flask(__name__)

# Process image and predict label
def processImg(IMG_PATH):
    # Load model
    with open("model.pkl", "rb") as f:
        model = pkl.load(f)
    
    # Read and preprocess image
    image = cv2.imread(IMG_PATH)
    image = cv2.resize(image, (28,28))[:,:,1]
    image = image.flatten()

    # Predict label
    predictions = model.predict(image.reshape(1,-1))

    return list(map(int, list(predictions)))

# %% [markdown]
# Render the webpage

# %%
@app.route("/")
def index():
    return render_template("indeex.html")

@app.route('/uploader', methods = ['POST'])
def upload_file():
    predictions=""

    if request.method == 'POST':
        f = request.files['file']
        f.save("static/img.jpg")    
        preds = processImg("static/img.jpg")
    
    return render_template("upload.html", predictions=preds, display_image="../img.jpg") 


if __name__ == "__main__":
    app.run()
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
# 127.0.0.1 - - [02/Apr/2026 18:35:03] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Apr/2026 18:35:03] "GET /static/css/main.css HTTP/1.1" 304 -
# 127.0.0.1 - - [02/Apr/2026 18:35:17] "POST /uploader HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Apr/2026 18:35:17] "GET /static/css/main.css HTTP/1.1" 304 -
# 127.0.0.1 - - [02/Apr/2026 18:35:17] "GET /static/img.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Apr/2026 18:35:26] "POST /uploader HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Apr/2026 18:35:26] "GET /static/css/main.css HTTP/1.1" 304 -
# 127.0.0.1 - - [02/Apr/2026 18:35:26] "GET /static/img.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Apr/2026 18:35:32] "POST /uploader HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Apr/2026 18:35:32] "GET /static/css/main.css HTTP/1.1" 304 -
# 127.0.0.1 - - [02/Apr/2026 18:35:32] "GET /static/img.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Apr/2026 18:36:00] "POST /uploader HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Apr/2026 18:36:00] "GET /static/css/main.css HTTP/1.1" 304 -
# 127.0.0.1 - - [02/Apr/2026 18:36:00] "GET /static/img.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Apr/2026 18:36:10] "POST /uploader HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Apr/2026 18:36:10] "GET /static/css/main.css HTTP/1.1" 304 -
# 127.0.0.1 - - [02/Apr/2026 18:36:10] "GET /static/img.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Apr/2026 18:36:15] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Apr/2026 18:36:15] "GET /static/css/main.css HTTP/1.1" 304 -
# 127.0.0.1 - - [02/Apr/2026 18:37:37] "POST /uploader HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Apr/2026 18:37:37] "GET /static/css/main.css HTTP/1.1" 304 -
# 127.0.0.1 - - [02/Apr/2026 18:37:37] "GET /static/img.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Apr/2026 18:37:56] "POST /uploader HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Apr/2026 18:37:56] "GET /static/css/main.css HTTP/1.1" 304 -
# 127.0.0.1 - - [02/Apr/2026 18:37:56] "GET /static/img.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Apr/2026 18:38:22] "POST /uploader HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Apr/2026 18:38:22] "GET /static/css/main.css HTTP/1.1" 304 -
# 127.0.0.1 - - [02/Apr/2026 18:38:22] "GET /static/img.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Apr/2026 18:38:30] "POST /uploader HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Apr/2026 18:38:30] "GET /static/css/main.css HTTP/1.1" 304 -
# 127.0.0.1 - - [02/Apr/2026 18:38:30] "GET /static/img.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Apr/2026 18:40:38] "POST /uploader HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Apr/2026 18:40:38] "GET /static/css/main.css HTTP/1.1" 304 -
# 127.0.0.1 - - [02/Apr/2026 18:40:38] "GET /static/img.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Apr/2026 18:42:18] "POST /uploader HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Apr/2026 18:42:18] "GET /static/css/main.css HTTP/1.1" 304 -
# 127.0.0.1 - - [02/Apr/2026 18:42:18] "GET /static/img.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Apr/2026 18:49:15] "POST /uploader HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Apr/2026 18:49:15] "GET /static/css/main.css HTTP/1.1" 304 -
# 127.0.0.1 - - [02/Apr/2026 18:49:15] "GET /static/img.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Apr/2026 18:49:56] "POST /uploader HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Apr/2026 18:49:56] "GET /static/css/main.css HTTP/1.1" 304 -
# 127.0.0.1 - - [02/Apr/2026 18:49:56] "GET /static/img.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Apr/2026 18:55:30] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Apr/2026 18:55:30] "GET /static/css/main.css HTTP/1.1" 304 -
# 127.0.0.1 - - [02/Apr/2026 18:55:52] "POST /uploader HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Apr/2026 18:55:52] "GET /static/css/main.css HTTP/1.1" 304 -
# 127.0.0.1 - - [02/Apr/2026 18:55:52] "GET /static/img.jpg HTTP/1.1" 200 -
